# %%
import pandas as pd
df = pd.read_excel('D:\\Q&A PDFS\\EastWestAirlines.xlsx', sheet_name='data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df = df.drop(columns=['ID#', 'Award?'])
df
#dropping these columns they can't be of any help in the clustering analysis
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
# dtypes: int64(10)
# memory usage: 312.6 KB

# %%
df.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
df.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# dtype: int64

# %%
df.shape
# Out:
# (3999, 10)

# %%
#visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
print(df['Balance'].value_counts())#numerical data
print(df['Qual_miles'].value_counts())#numerical data
print(df['cc1_miles'].value_counts())#categorical
print(df['cc2_miles'].value_counts())#categorical
print(df['cc3_miles'].value_counts())#categorical
print(df['Bonus_miles'].value_counts())#numerical data
print(df['Bonus_trans'].value_counts())#numerical data
print(df['Flight_miles_12mo'].value_counts())#numerical data
print(df['Flight_trans_12'].value_counts())#numerical data
print(df['Days_since_enroll'].value_counts())#numerical data
# Out:
# Balance
# 1000     10
# 500       5
# 2000      5
# 1500      4
# 5000      3
#          ..
# 9554      1
# 30130     1
# 12665     1
# 9860      1
# 3016      1
# Name: count, Length: 3904, dtype: int64
# Qual_miles
# 0       3773
# 1000      17
# 500       15
# 967        4
# 888        4
#         ...
# 4116       1
# 1388       1
# 1896       1
# 3692       1
# 1005       1
# Name: count, Length: 164, dtype: int64
# cc1_miles
# 1    2289
# 3     613
# 4     525
# 5     288
# 2     284
# Name: count, dtype: int64
# cc2_miles
# 1    3956
# 2      28
# 3      15
# Name: count, dtype: int64
# cc3_miles
# 1    3981
# 4       6
# 5       5
# 3       4
# 2       3
# Name: count, dtype: int64
# Bonus_miles
# 0        475
# 500       66
# 1000      42
# 100       27
# 1500      25
#         ...
# 11981      1
# 28904      1
# 9850       1
# 52449      1
# 25447      1
# Name: count, Length: 2734, dtype: int64
# Bonus_trans
# 0     475
# 14    262
# 3     250
# 13    231
# 15    212
# ...

# %%
#Standardizing the dataset as it is an essential part during clustering analysis

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
#KMeans - Clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
scaled_df['K_3'] = kmeans.fit_predict(scaled_df)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  K_3
# ...

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(scaled_df, scaled_df['K_3'])
score
# Out:
# 0.35099599819918265

# %%
#Elbow method to find the best number of clusters
scores = []

for i in range(2,11):
    cluster = KMeans(n_clusters=i)
    scaled_df["K_3"] = cluster.fit_predict(scaled_df)
    scores.append(silhouette_score(scaled_df,scaled_df["K_3"]))

scores


import matplotlib.pyplot as plt
plt.scatter(range(2,11), scores)
plt.plot(range(2,11), scores,color='red')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=9)
scaled_df['K_9'] = kmeans.fit_predict(scaled_df)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  K_3  \
# ...

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(scaled_df, scaled_df['K_9'])
score
# Out:
# 0.5344881802879928

# %%
#for the other k values the accuracy score is decreasing

# %%
#visualization of the KMeans clustering
plt.figure(figsize=(10, 6))
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df['K_9'], cmap='viridis', marker='o', s=50)
plt.title('K-Means Clustering Results (k=9)')
plt.xlabel('Balance')
plt.ylabel('Bonus_trans')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
# The K-Means analysis with k=9 shows some potential clusters based on Balance and Bonus_trans.
# Cluster 0 appears to represent customers with lower balance and lower bonus transactions.
# Cluster 1 might represent customers with higher bonus transactions but moderate balance.
# Cluster 2 seems to have moderate balance and lower bonus transactions.
# Cluster 3 shows very high balance and moderate bonus transactions.
# Cluster 4 represents customers with lower balance and moderate bonus transactions.
# Cluster 5 has moderate balance and higher bonus transactions.
# Cluster 6 shows high balance and lower bonus transactions.
# Cluster 7 seems to have moderate balance and moderate bonus transactions.
# Cluster 8 represents customers with very high bonus transactions and high balance.
# Further analysis of the mean values of other features within each cluster would provide a clearer picture of their characteristics.

# %%
#Since it's a 2D plot we can't show all dimensions(features) in the visualization.

# %%
#Reloading the dataset to perform the Hierarchial Clustering
import pandas as pd
df = pd.read_excel('D:\\Q&A PDFS\\EastWestAirlines.xlsx', sheet_name='data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df = df.drop(columns=['ID#', 'Award?'])
df
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.reset_index(drop=True, inplace=True)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
#Hierarchial Clustering
from sklearn.cluster import AgglomerativeClustering
cluster1 = AgglomerativeClustering(n_clusters=5,linkage='single')
scaled_df["Single"] = cluster1.fit_predict(scaled_df) #Single linkage clustering

cluster2 = AgglomerativeClustering(n_clusters=5,linkage='complete')
scaled_df["complete"] = cluster2.fit_predict(scaled_df) #complete linkage clustering

cluster3 = AgglomerativeClustering(n_clusters=5,linkage='average')
scaled_df["average"] = cluster3.fit_predict(scaled_df) #average linkage clustering

cluster4 = AgglomerativeClustering(n_clusters=5,linkage='ward')
scaled_df["ward"] = cluster4.fit_predict(scaled_df) #ward linkage clustering

scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# cluster formation -single-
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df["Single"], cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
score=silhouette_score(scaled_df,scaled_df["Single"])
print("single linkage score:", np.round(score,3))
# Out:
# single linkage score: 0.608

# %%
# cluster formation -complete-
import matplotlib.pyplot as plt
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df["complete"], cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
score=silhouette_score(scaled_df,scaled_df["complete"])
print("complete linkage score:", np.round(score,3))
# Out:
# complete linkage score: 0.677

# %%
# cluster formation -average- good
import matplotlib.pyplot as plt
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df["average"], cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
score=silhouette_score(scaled_df,scaled_df["average"])
print("average linkage score:", np.round(score,3))
# Out:
# average linkage score: 0.72

# %%
# cluster formation -ward
import matplotlib.pyplot as plt
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df["ward"], cmap='rainbow')  
plt.show()

from sklearn.metrics import silhouette_score
score=silhouette_score(scaled_df,scaled_df["ward"])
print("ward linkage score:", np.round(score,3))
# Out:
# ward linkage score: 0.358

# %%
# Analyze Hierarchial Clustering
# The Agglomerative clustering with different linkages shows varying results.
# Single linkage tends to form elongated clusters, which might not be ideal for this dataset based on the scatter plots. The silhouette score is low.
# Complete linkage provides a slightly better structure than single linkage based on the scatter plot, but the silhouette score is still not very high.
# Average linkage appears to produce more balanced clusters compared to single and complete linkage based on the scatter plot. The silhouette score is better than single and complete.
# Ward linkage seems to create more compact clusters and has the highest silhouette score among the Agglomerative methods tested, suggesting it might be the best fit for this dataset among the hierarchical methods explored.

# %%
import pandas as pd
df = pd.read_excel('D:\\Q&A PDFS\\EastWestAirlines.xlsx', sheet_name='data')
df
df = df.drop(columns=['ID#', 'Award?'])
df
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.reset_index(drop=True, inplace=True)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
from sklearn.cluster import DBSCAN
cluster = DBSCAN(eps=5,min_samples=20)
scaled_df["dbscan"] = cluster.fit_predict(scaled_df)

scaled_df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  dbscan
# 0    -1.104065          -0.328603        -0.362168           1.395454       0
# 1    -0.999926          -0.328603        -0.362168           1.379957       0
# 2    -0.791649          -0.328603        -0.362168           1.411920       0
# 3    -1.104065          -0.328603        -0.362168           1.372208       0
# 4     1.499394           1.154932         0.692490           1.363975       0

# %%
scaled_df["dbscan"].value_counts()
# Out:
# dbscan
#  0    3929
# -1      42
#  1      28
# Name: count, dtype: int64

# %%
scaled_df[scaled_df["dbscan"] == -1]

df_new = scaled_df[scaled_df["dbscan"] != -1]
df_new.shape
# Out:
# (3957, 11)

# %%
df_new.reset_index(drop=True, inplace=True)
df_new
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3952 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3953 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3954 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3955 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3956 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
score=silhouette_score(df_new,df_new["dbscan"])
print("dbscan linkage score:", np.round(score,3))
# Out:
# dbscan linkage score: 0.589

# %%
plt.figure(figsize=(10, 6))
plt.scatter(scaled_df['Balance'], scaled_df['Bonus_trans'], c=scaled_df['dbscan'], cmap='viridis', marker='o', s=50)
plt.title('DBSCAN Clustering Results')
plt.xlabel('Balance')
plt.ylabel('Bonus_trans')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
# Analyze DBSCAN Clustering
# DBSCAN with the chosen parameters identified a significant number of noise points (-1).
# The remaining points are grouped into two clusters (0 and 1).
# Cluster 0 seems to represent the majority of the data points, likely the 'typical' customers.
# Cluster 1 appears to be a smaller cluster, potentially representing a group with different characteristics, possibly related to outlier-like behavior in some features that the epsilon parameter allowed them to cluster together.
# The silhouette score for DBSCAN is calculated on the non-noise points and is quite good, indicating well-separated clusters among the identified groups, excluding the outliers.
# The scatter plot for DBSCAN visually highlights the two main clusters and the scattered noise points.

# %%
# Overall Insights:
# K-Means (with k=9) and Agglomerative Clustering (Ward linkage) seem to provide potentially meaningful groupings of customers based on the features.
# DBSCAN identifies potential outliers and separates them, which can be valuable for understanding unusual customer behavior.
# The choice of the best clustering algorithm and the optimal number of clusters depends on the specific business goals and the interpretation of the cluster characteristics.
# To get a comprehensive understanding of each cluster's profile for all algorithms, it's essential to calculate the mean (or median) values of all original features within each cluster and interpret these values in the context of the airline's data.
